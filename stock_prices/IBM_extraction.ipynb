# %% [markdown]
# ### Extract and clean all data on IBM in 2024. Push to SQL database.

# %%
import pandas as pd
import requests

# A Python file I made myself with all the functions for cleaning and extracting:
import alpha_vantage

# %%
months = [
    '2024-01',
    '2024-02',
    '2024-03',
    '2024-04',
    '2024-05',
    '2024-06'
]

IBM_2024 = pd.DataFrame()

for month in months:
    df_raw = alpha_vantage.extracting_api(equity='IBM',time_interval='5',month=month)
    df_cleaned = alpha_vantage.cleaning(df_raw)
    IBM_2024 = pd.concat([IBM_2024,df_cleaned])
# Out:
# c:\Users\44771\Documents\Repo\Data_projects_24\alpha_vantage.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['date', 'time']] = df['datetime'].str.split(' ', expand=True)
# c:\Users\44771\Documents\Repo\Data_projects_24\alpha_vantage.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['date', 'time']] = df['datetime'].str.split(' ', expand=True)
# c:\Users\44771\Documents\Repo\Data_projects_24\alpha_vantage.py:48: SettingWithCopyWarning:
# ...

# %%
IBM_2024
# Out:
#            date      time     open     high      low    close     volume
# 0    2024-01-02  04:00:00  162.077  162.617  162.068  162.616       16.0
# 1    2024-01-02  04:05:00  162.176  162.627  162.167  162.626        3.0
# 2    2024-01-02  04:10:00  162.176  162.538  162.167  162.487       58.0
# 3    2024-01-02  04:20:00  162.473  162.488  162.167  162.487       16.0
# 4    2024-01-02  04:45:00  162.285  162.637  162.276  162.576      592.0
# ...         ...       ...      ...      ...      ...      ...        ...
# 2219 2024-06-21  19:00:00  172.460  172.460  172.460  172.460  3143611.0
# 2220 2024-06-21  19:30:00  172.480  172.480  172.480  172.480       14.0
# 2221 2024-06-21  19:40:00  172.490  172.490  172.490  172.490      205.0
# 2222 2024-06-21  19:50:00  172.460  172.500  172.460  172.500       13.0
# 2223 2024-06-21  19:55:00  172.480  172.480  172.480  172.480        3.0
#
# [19518 rows x 7 columns]

# %% [markdown]
# ### Checks:
# ### Overall info- non-null count of data-type.
# ### Describe- mean, min, max, std, quartile ranges for each column.
# ### Count of null and duplicated values.

# %%
IBM_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19518 entries, 0 to 2223
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    19518 non-null  datetime64[ns]
#  1   time    19518 non-null  object
#  2   open    19518 non-null  float64
#  3   high    19518 non-null  float64
#  4   low     19518 non-null  float64
#  5   close   19518 non-null  float64
#  6   volume  19518 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 1.2+ MB

# %%
IBM_2024.describe().T
# Out:
#           count                           mean                  min  \
# date      19518  2024-03-27 02:34:29.474331392  2024-01-02 00:00:00
# open    19518.0                     177.263794              156.537
# high    19518.0                     177.394954              157.028
# low     19518.0                     177.117842              145.297
# close   19518.0                     177.256937              156.501
# volume  19518.0                   47140.373655                  0.0
#
#                         25%                  50%                  75%  \
# date    2024-02-13 00:00:00  2024-03-26 00:00:00  2024-05-09 00:00:00
# open                167.543              180.659              186.178
# high                 167.65              180.897              186.324
# low                  167.44              180.453            186.03775
# close               167.544              180.667               186.16
# ...

# %%
IBM_2024.isnull().sum()
# Out:
# date      0
# time      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
IBM_2024.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'} Can only do 25 requests per day with free version.

# %%
'''
df.info()
df.describe().T
df.isnull().sum()
df=df.fillna(0)
df.duplicated().sum()
'''
